# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.6/755.6 kB 10.3 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
cd /content/drive/MyDrive/mydentalProject/classification
# Out:
# /content/drive/MyDrive/mydentalProject/classification

# %%
DATA_DIR = '/content/drive/MyDrive/mydentalProject/classification/datasetClassification'

# %%
import os
from ultralytics import YOLO
model = YOLO("yolov8n-cls.pt")
results = model.train(data=DATA_DIR, epochs=20)
# Out:
# ...
# 100%|██████████| 5.30M/5.30M [00:00<00:00, 80.0MB/s]
# Ultralytics YOLOv8.2.10 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import numpy as np
import re
import torch
model = YOLO('/content/drive/MyDrive/mydentalProject/classification/runs/classify/train/weights/best.pt')

predict = model('/content/drive/MyDrive/mydentalProject/classification/mandible.jpg')
names_dict = predict[0]
# print(names_dict)
# probs = predict[0].probs
# print(probs.top5conf[0])
a = str(probs.top5conf[0])
number = re.search(r'\d+\.\d+', a).group()
number = float(number)

print(number)
# print(names_dict[np.argmax(number)])
# Out:
# image 1/1 /content/drive/MyDrive/mydentalProject/classification/mandible.jpg: 224x224 Mandible 0.86, Maxilla 0.14, 4.0ms
# Speed: 62.7ms preprocess, 4.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 0.8568

# %%
import numpy as np
from ultralytics import YOLO
import re
import torch
model = YOLO('/content/drive/MyDrive/mydentalProject/classification/runs/classify/train/weights/best.pt')

predict = model('/content/drive/MyDrive/mydentalProject/classification/mandible.jpg')

names_dict = predict[0].names
output = predict[0].probs.data.tolist()

# output = [float(x) for x in output]

print(names_dict)
print(output)

print("the image is :- "+ names_dict[np.argmax(output)])
# Out:
# image 1/1 /content/drive/MyDrive/mydentalProject/classification/mandible.jpg: 224x224 Mandible 0.86, Maxilla 0.14, 3.3ms
# Speed: 40.9ms preprocess, 3.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# {0: 'Mandible', 1: 'Maxilla'}
# [0.8567776679992676, 0.143222376704216]
# the image is :- Mandible
